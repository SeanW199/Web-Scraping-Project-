# %%
from bs4 import BeautifulSoup
import requests as request
import pandas as pd
import os

# %%
startpage = 1
endPage = 0
maxPages = []
df = pd.DataFrame(columns=['Name','Title','Text','Rating', 'Date of Experience', 'Date Posted'])
url = 'https://uk.trustpilot.com/review/www.matalan.co.uk?page=' + str(startpage)

# %%
page = request.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
totalPages = soup.find_all('a', class_="link_internal__7XN06 button_button__T34Lr button_m__lq0nA button_appearance-outline__vYcdF button_squared__21GoE link_button___108l pagination-link_item__mkuN3")
for totalPages in totalPages:
    n = totalPages.find('span',class_='typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7').text
    maxPages.append(int(n))
endPage = max(maxPages)

# %%
   
reviews = soup.find_all('div', class_="styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ")
for review in reviews: 
#     data = []
    name = review.find('span', class_="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17").text

    rating = review.find('div', class_="star-rating_starRating__4rrcf star-rating_medium__iN6Ty")
    rating = rating.find('img')
    rating = rating.attrs['alt']
    
    title = review.find('h2', class_="typography_heading-s__f7029 typography_appearance-default__AAY17").text
    
    text = review.find('p', class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").text
    
    doe = review.find('p', class_="typography_body-m__xgxZ_ typography_appearance-default__AAY17 typography_color-black__5LYEn").text

    posted = review.find('time')
    posted = posted.get('datetime') 
#     data.extend([[name,title,text,rating,doe,posted]])
    df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# Out:
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)
# C:\Users\seanw\AppData\Local\Temp\ipykernel_18524\1303516091.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name,'Title': title,'Text': text,'Rating': rating, 'Date of Experience': doe, 'Date Posted': posted}, ignore_index=True)

# %%
# df.drop_duplicates()
df
# Out:
#                 Name                                              Title  \
# 0     Audrey Gateley             Ordered 3 pack of hipsters and 5 pack…
# 1       Mrs Alison                  21 days & still no sign of my order
# 2               Linz                              Will my item arrive?!
# 3             Simon                  Matalan click and collect in store
# 4                zoe           I have to say this is very poor service…
# 5             Hannah  Had a faulty item delivered - avoid as you get...
# 6           J Hughes                            Furniture delivery poor
# 7              K-Dog                                    Good experience
# 8                Jaz  Placed an order with Matalan on the 18th Nov s...
# 9     Chelsea Ewings             Never will I order from Matalan again!
# 10  Ms Lesley Cassar                                   Dreadful service
# 11     mary lawrence            Rotten policies regarding money refunds
# 12            Emily            I have now written to Trading Standards…
# 13        Jean Jones               Ordered goods on 17th nov still not…
# 14     Nigel boulton          Don’t shop there unless you want to queue
# 15       Laura Booth   So update on my already disappointing experience
# 16          customer                             Worst customer service
# 17             12345                 Just a follow up from my previous…
# 18       Bob Goodall                                        What a sham
# 19             Sarah              ROBBED ME AND WON'T GIVE MY REFUND!!!
#
#                                                  Text                  Rating  \
# 0   Ordered 3 pack of hipsters and 5 pack of nicke...  Rated 1 out of 5 stars
# 1   I placed an order on the 8th November. 21 days...  Rated 1 out of 5 stars
